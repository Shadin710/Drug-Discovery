# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn import linear_model
from sklearn import svm
import joblib
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
from PIL import Image
import PIL
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv",na_values={
    'bioactivity_class':['intermediate']
})
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1098      CHEMBL4640021  N=C(N)Nc1ccc(CNC(=O)[C@@H](NC(=O)Cc2ccc(-c3ccc...
# 1099      CHEMBL4642885  CCCCCC(=O)N[C@@H](C(=O)NCc1ccc(CN)cc1)c1ccc(OC...
# 1100      CHEMBL4636584  N=C(N)NCc1ccc(CNC(=O)[C@H](NC(=O)c2ccc(Oc3cccc...
# 1101      CHEMBL4633312  N=C(N)Nc1ccc(CNC(=O)[C@@H](NC(=O)Cc2ccc(-c3ccc...
# 1102      CHEMBL4643526  N=C(N)Nc1ccc(CNC(=O)[C@@H](NC(=O)c2ccc(-c3cccs...
#
#      bioactivity_class  standard_value
# 0             inactive        100000.0
# 1             inactive         12310.0
# 2             inactive        100000.0
# 3             inactive         50970.0
# 4             inactive        100000.0
# ...                ...             ...
# 1098               NaN          1300.0
# 1099               NaN          3100.0
# 1100               NaN          2500.0
# 1101            active           540.0
# 1102               NaN          6300.0
#
# [1103 rows x 4 columns]

# %%
clean = df.fillna({
    'bioactivity_class':'active',
    'canonical_smiles': 'COc1ccc2nc3cccc(OC)c3nc2c1'
})
clean.dropna()
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1098      CHEMBL4640021  N=C(N)Nc1ccc(CNC(=O)[C@@H](NC(=O)Cc2ccc(-c3ccc...
# 1099      CHEMBL4642885  CCCCCC(=O)N[C@@H](C(=O)NCc1ccc(CN)cc1)c1ccc(OC...
# 1100      CHEMBL4636584  N=C(N)NCc1ccc(CNC(=O)[C@H](NC(=O)c2ccc(Oc3cccc...
# 1101      CHEMBL4633312  N=C(N)Nc1ccc(CNC(=O)[C@@H](NC(=O)Cc2ccc(-c3ccc...
# 1102      CHEMBL4643526  N=C(N)Nc1ccc(CNC(=O)[C@@H](NC(=O)c2ccc(-c3cccs...
#
#      bioactivity_class  standard_value
# 0             inactive        100000.0
# 1             inactive         12310.0
# 2             inactive        100000.0
# 3             inactive         50970.0
# 4             inactive        100000.0
# ...                ...             ...
# 1098            active          1300.0
# 1099            active          3100.0
# 1100            active          2500.0
# 1101            active           540.0
# 1102            active          6300.0
#
# [1103 rows x 4 columns]

# %%
cou = 0
for i in clean['canonical_smiles']:
    img = Chem.MolFromSmiles(i)
    get_img  = Chem.Draw.MolToImage(img)
    get_img.save(f"./image/img_{cou}.jpg")
    cou= cou+1

# %%
m  = Chem.MolFromSmiles("OCCc1c(C)[n+](cs1)Cc2cnc(C)nc2N")
m1 = Chem.Draw.MolToImage(m)
m1.save("n.jpg")
